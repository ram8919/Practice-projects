# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %%
# data=pd.read_csv('happiness_score_dataset.csv')

# %%
data=pd.read_csv('C:\\Users\\Bawla Singh.DESKTOP-KT1PI9D\\Desktop\\Ram\\Files-main\\DSData-master\\happiness_score_dataset.csv')

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_columns=['Country','Region','Happiness Rank','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']

# %%
data=data[data_columns].copy()

# %%
happy_data=data.rename({'Country':'Country_name','Region':'Regional','Happiness Rank':'Happiness_Rank','Happiness Score':'Happiness_Score','Economy (GDP per Capita)':'GDP_per_Capita','Family':'Family_Rank','Health (Life Expectancy)':'Life_Expectancy','Freedom':'Freedom_life','Trust (Government Corruption)':'Government_Corruption','Generosity':'Generosity','Dystopia Residual':'Dystopia_Residual'},axis=1)

# %%
happy_data.head()
# Out:
#   Country_name        Regional  Happiness_Rank  Happiness_Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    GDP_per_Capita  Family_Rank  Life_Expectancy  Freedom_life  \
# 0         1.39651      1.34951          0.94143       0.66557
# 1         1.30232      1.40223          0.94784       0.62877
# 2         1.32548      1.36058          0.87464       0.64938
# 3         1.45900      1.33095          0.88521       0.66973
# 4         1.32629      1.32261          0.90563       0.63297
#
#    Government_Corruption  Generosity  Dystopia_Residual
# 0                0.41978     0.29678            2.51738
# 1                0.14145     0.43630            2.70201
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize']=(15,10)
plt.title('plot between Happiness Score and GDP_per_Capita')
sns.scatterplot(x = happy_data.Happiness_Score ,y = happy_data.GDP_per_Capita,hue =happy_data.Regional,s=200);

plt.legend(loc='upper left',fontsize='12')
plt.xlabel('Happiness Score')
plt.ylabel('Economy(GDP per Capita)')
plt.rcParams['figure.facecolor']='blue'
sns.set_style('darkgrid')

# %%
sns.scatterplot(x='Region',y='Happiness Rank',data=data)
plt.rcParams['figure.figsize']=(10,15)
plt.title('plot between Happiness Score and GDP_per_Capita')

plt.xlabel('Happiness Score')
plt.ylabel('Economy(GDP per Capita)')
plt.rcParams['figure.facecolor']='blue'
sns.set_style('darkgrid')

# %%
GDP_region=happy_data.groupby('Regional')['GDP_per_Capita'].sum()
GDP_region
# Out:
# Regional
# Australia and New Zealand           2.58376
# Central and Eastern Europe         27.33071
# Eastern Asia                        6.91068
# Latin America and Caribbean        19.28994
# Middle East and Northern Africa    21.33947
# North America                       2.72080
# Southeastern Asia                   7.10149
# Southern Asia                       3.92340
# Sub-Saharan Africa                 15.21892
# Western Europe                     27.27051
# Name: GDP_per_Capita, dtype: float64

# %%
GDP_region.plot.pie(autopct='%1.1f%%')
plt.title('GDP by region')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
happy_data.corr
# Out:
# <bound method DataFrame.corr of     Country_name                         Regional  Happiness_Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  GDP_per_Capita  Family_Rank  Life_Expectancy  \
# 0              7.587         1.39651      1.34951          0.94143
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(happy_data.corr(), annot=True,linewidths=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
happy_data.describe()
# Out:
#        Happiness_Rank  Happiness_Score  GDP_per_Capita  Family_Rank  \
# count      158.000000       158.000000      158.000000   158.000000
# mean        79.493671         5.375734        0.846137     0.991046
# std         45.754363         1.145010        0.403121     0.272369
# min          1.000000         2.839000        0.000000     0.000000
# 25%         40.250000         4.526000        0.545808     0.856823
# 50%         79.500000         5.232500        0.910245     1.029510
# 75%        118.750000         6.243750        1.158448     1.214405
# max        158.000000         7.587000        1.690420     1.402230
#
#        Life_Expectancy  Freedom_life  Government_Corruption  Generosity  \
# count       158.000000    158.000000             158.000000  158.000000
# mean          0.630259      0.428615               0.143422    0.237296
# std           0.247078      0.150693               0.120034    0.126685
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(round(happy_data.describe()[1:].transpose(),2),linewidths=2,annot=True  ,fmt='.2f')
plt.xticks(fontsize=10)
plt.yticks(fontsize=8)
plt.title('Happiness_Score')
plt.show()

# %%
happy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country_name           158 non-null    object
#  1   Regional               158 non-null    object
#  2   Happiness_Rank         158 non-null    int64
#  3   Happiness_Score        158 non-null    float64
#  4   GDP_per_Capita         158 non-null    float64
#  5   Family_Rank            158 non-null    float64
#  6   Life_Expectancy        158 non-null    float64
#  7   Freedom_life           158 non-null    float64
#  8   Government_Corruption  158 non-null    float64
#  9   Generosity             158 non-null    float64
#  10  Dystopia_Residual      158 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.7+ KB

# %%
Corruption=happy_data.groupby('Regional')[['Government_Corruption']].mean()
Corruption
# Out:
#                                  Government_Corruption
# Regional
# Australia and New Zealand                     0.392795
# Central and Eastern Europe                    0.086674
# Eastern Asia                                  0.127695
# Latin America and Caribbean                   0.117172
# Middle East and Northern Africa               0.181702
# North America                                 0.244235
# Southeastern Asia                             0.151276
# Southern Asia                                 0.102536
# Sub-Saharan Africa                            0.123878
# Western Europe                                0.231463

# %%
plt.rcParams['figure.figsize']=(12,8)
plt.title('Perception of corruption in verious Regions')
plt.xlabel('Regions', fontsize=15)
plt.ylabel('Corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(Corruption.index, Corruption.Government_Corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.rcParams['figure.figsize']=(15,10)
sns.scatterplot(x = happy_data.Freedom_life ,y = happy_data.Happiness_Score,hue =happy_data.Regional,s=200);

plt.legend(loc='upper left',fontsize='12')
plt.xlabel('freedom of life')
plt.ylabel('happiness_score')
plt.rcParams['figure.facecolor']='blue'
sns.set_style('darkgrid')

# %%
Country=happy_data.sort_values(by='Government_Corruption').head(10)
plt.rcParams['figure.figsize']=(12,8)
plt.title('Countries with most Government_Corruption')
plt.xlabel('Regions', fontsize=15)
plt.ylabel('Corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(Country.Country_name, Country.Government_Corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
Country=happy_data.sort_values(by='Government_Corruption').tail(10)
plt.rcParams['figure.figsize']=(12,8)
plt.title('Countries with most Government_Corruption')
plt.xlabel('Regions', fontsize=15)
plt.ylabel('Corruption Index',fontsize=15)
plt.xticks(rotation=30,ha='right')
plt.bar(Country.Country_name, Country.Government_Corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.rcParams['figure.figsize']=(15,10)
sns.scatterplot(x = happy_data.Happiness_Score ,y = happy_data.Government_Corruption,hue =happy_data.Regional,s=200);

plt.legend(loc='upper left',fontsize='12')
plt.xlabel('Happiness Score')
plt.ylabel('Corruption')
plt.rcParams['figure.facecolor']='blue'
sns.set_style('darkgrid')

# %%
happy_data.skew()
# Out:
# Happiness_Rank           0.000418
# Happiness_Score          0.097769
# GDP_per_Capita          -0.317575
# Family_Rank             -1.006893
# Life_Expectancy         -0.705328
# Freedom_life            -0.413462
# Government_Corruption    1.385463
# Generosity               1.001961
# Dystopia_Residual       -0.238911
# dtype: float64

# %%
sns.distplot(happy_data['Happiness_Rank'])
plt.rcParams['figure.figsize']=(10,5)
# Out:
# C:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(happy_data['Happiness_Score'])
plt.rcParams['figure.figsize']=(10,5)
# Out:
# C:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(happy_data['GDP_per_Capita'])
plt.rcParams['figure.figsize']=(10,5)
# Out:
# C:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(happy_data['Government_Corruption'])
plt.rcParams['figure.figsize']=(10,5)
# Out:
# C:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
